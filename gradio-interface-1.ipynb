# %%
import gradio as gr

# Simple function
def greet(name):
    return f"Hello, {name}! Welcome to your Gradio Interface"

# Create interface
demo = gr.Interface(
    fn=greet,                   # Function to run
    inputs=gr.Textbox(label="Enter your name"),
    outputs=gr.Textbox(label="Greeting"),
    title="Basic Gradio App",
    description="A very simple example interface using Gradio.",
)

# Launch the interface
demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# * Running on public URL: https://c3cb011d8fe78aaaf7.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c3cb011d8fe78aaaf7.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
