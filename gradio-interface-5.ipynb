# %%
import gradio as gr

# Word Lists
positive_words = ["good", "great", "happy", "excellent", "amazing"]
negative_words = ["bad", "sad", "angry", "terrible", "poor"]

# Function for sentiment analysis
def analyze_sentiment(text):
    text_lower = text.lower()
    if any(word in text_lower for word in positive_word):
        return "Positive sentiment"
    elif any(word in text_lower for word in negative_words):
        return "Negative sentiment"
    else:
        return "Neutral sentiment"

# Gradio Interface
demo = gr.Interface(
    fn=analyze_sentiment,
    inputs=gr.Textbox(label="Enter text here"),
    outputs=gr.Textbox(label="Sentiment Result"),
    title="Simple Sentiment Analyzer",
    description="A rule-based sentiment detection demo."
)

demo.launch()
